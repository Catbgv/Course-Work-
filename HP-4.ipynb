# %% [markdown]
# ![](blake-johnson-animation-test.gif)

# %% [markdown]
# I have developed this game inspired in the Harry Potter series. I established 4 stages where the player will have to collect the three Deathly Hallows in order to win the game: The invisibility cloak, the elder wand and the resurrection stone. The game begins with the sorting hat event where the player will have to be placed in a house: Gryffindor, Hufflepuff, Ravenclaw, or Slytherin based on their personal traits. Suddenly, Voldemort interrupts the Sorting event and Harry leads the way between the different stages.
# The second stage is the Griffyndor Common Room to collect the invisibility cloak. In this stage I used the shuffle function in order to make the player guess the password to enter, which is Caput Draconis.
# The third, Dumbledore's Office also has a password, but I made it a list where the player can pick an alternative in order to guess the correct password and collect the Elder wand.
# The final stage is a battle with Voldemort. Here I used a for loop in order to make the attacks between the player and Voldermort fast and simultaneous to the story board. After defeating Voldemort, the player will earn the last Deathly Hallow.
# At the end Dumbledore salutes the player, gives him or her the resurrection stone, says some last words and with that the player wins!

# %%
# I used ASCII to Welcome the player to the Wizarding World of Harry Potter
print(""" \033[1;33m
▄▄▌  ▄▄▄ .▄▄▄▄▄.▄▄ ·      ▄▄ •           ▄▄▄▄▄          
██•  ▀▄.▀·•██  ▐█ ▀.     ▐█ ▀ ▪▪         •██  ▪         
██▪  ▐▀▀▪▄ ▐█.▪▄▀▀▀█▄    ▄█ ▀█▄ ▄█▀▄      ▐█.▪ ▄█▀▄     
▐█▌▐▌▐█▄▄▌ ▐█▌·▐█▄▪▐█    ▐█▄▪▐█▐█▌.▐▌     ▐█▌·▐█▌.▐▌    
.▀▀▀  ▀▀▀  ▀▀▀  ▀▀▀▀     ·▀▀▀▀  ▀█▄▀▪     ▀▀▀  ▀█▄▀▪    
 ▄ .▄       ▄▄ • ▄▄▌ ▐ ▄▌ ▄▄▄· ▄▄▄  ▄▄▄▄▄.▄▄ ·          
██▪▐█▪     ▐█ ▀ ▪██· █▌▐█▐█ ▀█ ▀▄ █·•██  ▐█ ▀.          
██▀▐█ ▄█▀▄ ▄█ ▀█▄██▪▐█▐▐▌▄█▀▀█ ▐▀▀▄  ▐█.▪▄▀▀▀█▄         
██▌▐▀▐█▌.▐▌▐█▄▪▐█▐█▌██▐█▌▐█ ▪▐▌▐█•█▌ ▐█▌·▐█▄▪▐█         
▀▀▀ · ▀█▄▀▪·▀▀▀▀  ▀▀▀▀ ▀▪ ▀  ▀ .▀  ▀ ▀▀▀  ▀▀▀▀   """ )

print(r""" 
                             .-----.
                          .'       `.
                         :      ^v^  :
                         :           :
                         '           '
          |~        www   `.       .'
         /.\       /#^^\_   `-/\--'
        /#  \     /#%    \   /# \
       /#%   \   /#%______\ /#%__\
      /#%     \   |= I I ||  |- |
      ~~|~~~|~~   |_=_-__|'  |[]|
        |[] |_______\__|/_ _ |= |`.
 ^V^    |-  /= __   __    /-\|= | :;
        |= /- /\/  /\/   /=- \.-' :;
        | /_.=========._/_.-._\  .:'
        |= |-.'.- .'.- |  /|\ |.:'
        \  |=|:|= |:| =| |~|~||'|
         |~|-|:| -|:|  |-|~|~||=|      ^V^
         |=|=|:|- |:|- | |~|~|| |
         | |-_~__=_~__=|_^^^^^|/___
         |-(=-=-=-=-=-(|=====/=_-=/\
         | |=_-= _=- _=| -_=/=_-_/__\
         | |- _ =_-  _-|=_- |]#| I II
         |=|_/ \_-_= - |- = |]#| I II
         | /  _/ \. -_=| =__|]!!!I_II!!
        _|/-'/  ` \_/ \|/' _ ^^^^`.==_^.
      _/  _/`-./`-; `-.\_ / \_'\`. `. ===`.
     / .-'  __/_   `.   _/.' .-' `-. ; ====;\
    /. jgs./    \ `. \ / -  /  .-'.' ====='  >
   /  \  /  .-' `--.  / .' /  `-.' ======.' /
""" ) 


#Welcoming the player to the game
print(f"""
\033[0;30m
{'/' * 50}

⚡️Welcome to the Wizarding World of Harry Potter⚡️!

{'/' * 50}\n""")

#I´m defining how to win in the game by defeating Voldermort

def win():
    print("You made it! You defeated Voldemort! I hope you enjoyed this wonderful adventure!")

import sys
#I´m defining how to fail in the game with an image of a troll
def fail():
    print(r""" You lost
               _......._
       .-'.'.'.'.'.'.`-.
     .'.'.'.'.'.'.'.'.'.`.
    /.'.'               '.\
    |.'    _.--...--._     |
    \    `._.-.....-._.'   /
    |     _..- .-. -.._   |
 .-.'    `.   ((@))  .'   '.-.
( ^ \      `--.   .-'     / ^ )
 \  /         .   .       \  /
 /          .'     '.  .-    \
( _.\    \ (_`-._.-'_)    /._\)
 `-' \   ' .--.          / `-'
     |  / /|_| `-._.'\   |
     |   |       |_| |   /-.._
 _..-\   `.--.______.'  |
      \       .....     |
       `.  .'      `.  /
         \           .'
  LGB     `-..___..-`
  """)
    sys.exit(0)
    

input("Press to < Enter > this magical world! ✨\n""")

#This is the first stage, where the sorting hat event will occur. 
# Get the player's name to personalize the scripts

name_prompt = "What is your name?\n "
name = input(name_prompt)
print(f"""\nYou are just in time for the Sorting Hat, {name}🪄,
    it´s time to place you into your appropriate house."""  )


def great_hall_stg1():
    
    # The Loop is used here to guarantee get players sorted into their houses
    player_not_sorted = True
    while player_not_sorted:
#This is the question they have to answer
        sorting_hat = input("""
        Tell me, which of these options would you choose?
            A. Bravery, helping others, and chivalry
            B. Hard work, patience, loyalty, and fair play
            C. Intelligence, knowledge, planning ahead, and wit
            D. Ambition, cunningness, heritage, and resourcefulness
        """)


        # I used ASCII to add some creativity when sorted into a house with the conditional statement by choosing the words in the alternative
        if 'Bravery, helping others, and chivalry' in sorting_hat:
            print("""
       _____      _  __  __ _           _            
      / ____|    (_)/ _|/ _(_)         | |           
     | |  __ _ __ _| |_| |_ _ _ __   __| | ___  _ __ 
     | | |_ | '__| |  _|  _| | '_ \ / _` |/ _ \| '__|
     | |__| | |  | | | | | | | | | | (_| | (_) | |   
      \_____|_|  |_|_| |_| |_|_| |_|\__,_|\___/|_|
                  """)


        elif 'Hard work, patience, loyalty, and fair play' in sorting_hat:
            print("""
     _  _ _  _ ____ ____ __   ____ ____ _  _ ____ ____ 
    / )( / )( (  __(  __(  ) (  __(  _ / )( (  __(  __)
    ) __ ) \/ () _) ) _)/ (_/\) _) ) __) \/ () _) ) _) 
    \_)(_\____(__) (__) \____(____(__) \____(__) (__) 
    """)

        elif 'Intelligence, knowledge, planning ahead, and wit' in sorting_hat:
            print("""
         ______   ________  __   __  ______  ___   __   ______  __      ________  __ __ __      
         ▄██▀▀▀███▀▀▀██▄ ███    ███   ███    ███   ███    ███ ███         ███    ███                 
         ███   ███   ███ ███    ███   ███    █▀    ███    █▀  ███         ███    █▀                  
         ███   ███   ███ ███    ███  ▄███         ▄███        ███        ▄███▄▄▄                     
         ███   ███   ███ ███    ███ ▀▀███ ████▄  ▀▀███ ████▄  ███       ▀▀███▀▀▀                     
         ███   ███   ███ ███    ███   ███    ███   ███    ███ ███         ███    █▄                  
         ███   ███   ███ ███    ███   ███    ███   ███    ███ ███▌    ▄   ███    ███                 
          ▀█   ███   █▀  ████████▀    ████████▀    ████████▀  █████▄▄██   ██████████                 
                                                              ▀                      

                  """)

        elif sorting_hat.lower() == 'a':
            player_not_sorted = False
            print("""
       _____      _  __  __ _           _            
      / ____|    (_)/ _|/ _(_)         | |           
     | |  __ _ __ _| |_| |_ _ _ __   __| | ___  _ __ 
     | | |_ | '__| |  _|  _| | '_ \ / _` |/ _ \| '__|
     | |__| | |  | | | | | | | | | | (_| | (_) | |   
      \_____|_|  |_|_| |_| |_|_| |_|\__,_|\___/|_|   

                  """)

        elif sorting_hat.lower() == 'b':
            player_not_sorted = False
            print("""
     _  _ _  _ ____ ____ __   ____ ____ _  _ ____ ____ 
    / )( / )( (  __(  __(  ) (  __(  _ / )( (  __(  __)
    ) __ ) \/ () _) ) _)/ (_/\) _) ) __) \/ () _) ) _) 
    \_)(_\____(__) (__) \____(____(__) \____(__) (__) 
                  """)


        elif sorting_hat.lower() == 'c':
            player_not_sorted = False
            print("""
      _______ _______         _______ _       _______ _       _______         
    (  ____ (  ___  |\     /(  ____ ( (    /(  ____ ( \     (  ___  |\     /|
    | (    )| (   ) | )   ( | (    \|  \  ( | (    \| (     | (   ) | )   ( |
    | (____)| (___) | |   | | (__   |   \ | | |     | |     | (___) | | _ | |
    |     __|  ___  ( (   ) |  __)  | (\ \) | |     | |     |  ___  | |( )| |
    | (\ (  | (   ) |\ \_/ /| (     | | \   | |     | |     | (   ) | || || |
    | ) \ \_| )   ( | \   / | (____/| )  \  | (____/| (____/| )   ( | () () |
    |/   \__|/     \|  \_/  (_______|/    )_(_______(_______|/     \(_______)


                  """)

        elif sorting_hat.lower() == 'd':
            player_not_sorted = False
            print("""
          ██████ ██▓  ▓██   ██▄▄▄█████▓██░ ██▓█████ ██▀███  ██▓███▄    █ 
        ▒██    ▒▓██▒   ▒██  ██▓  ██▒ ▓▓██░ ██▓█   ▀▓██ ▒ ██▓██▒██ ▀█   █ 
        ░ ▓██▄  ▒██░    ▒██ ██▒ ▓██░ ▒▒██▀▀██▒███  ▓██ ░▄█ ▒██▓██  ▀█ ██▒
          ▒   ██▒██░    ░ ▐██▓░ ▓██▓ ░░▓█ ░██▒▓█  ▄▒██▀▀█▄ ░██▓██▒  ▐▌██▒
        ▒██████▒░██████▒░ ██▒▓░ ▒██▒ ░░▓█▒░██░▒████░██▓ ▒██░██▒██░   ▓██░
        ▒ ▒▓▒ ▒ ░ ▒░▓  ░ ██▒▒▒  ▒ ░░   ▒ ░░▒░░░ ▒░ ░ ▒▓ ░▒▓░▓ ░ ▒░   ▒ ▒ 
        ░ ░▒  ░ ░ ░ ▒  ▓██ ░▒░    ░    ▒ ░▒░ ░░ ░  ░ ░▒ ░ ▒░▒ ░ ░░   ░ ▒░
        ░  ░  ░   ░ ░  ▒ ▒ ░░   ░      ░  ░░ ░  ░    ░░   ░ ▒ ░  ░   ░ ░ 
              ░     ░  ░ ░             ░  ░  ░  ░  ░  ░     ░          ░ 
                       ░ ░                                              
                  """)

        else:
            print(r"""

        ████████▄   ▄██████▄  ███▄▄▄▄       ███          ▀█████████▄     ▄████████         ▄████████ 
        ███   ▀███ ███    ███ ███▀▀▀██▄ ▀█████████▄        ███    ███   ███    ███        ███    ███ 
        ███    ███ ███    ███ ███   ███    ▀███▀▀██        ███    ███   ███    █▀         ███    ███ 
        ███    ███ ███    ███ ███   ███     ███   ▀       ▄███▄▄▄██▀   ▄███▄▄▄            ███    ███ 
        ███    ███ ███    ███ ███   ███     ███          ▀▀███▀▀▀██▄  ▀▀███▀▀▀          ▀███████████ 
        ███    ███ ███    ███ ███   ███     ███            ███    ██▄   ███    █▄         ███    ███ 
        ███   ▄███ ███    ███ ███   ███     ███            ███    ███   ███    ███        ███    ███ 
        ████████▀   ▀██████▀   ▀█   █▀     ▄████▀        ▄█████████▀    ██████████        ███    █▀  

           ▄▄▄▄███▄▄▄▄   ███    █▄     ▄██████▄     ▄██████▄   ▄█          ▄████████                 
         ▄██▀▀▀███▀▀▀██▄ ███    ███   ███    ███   ███    ███ ███         ███    ███                 
         ███   ███   ███ ███    ███   ███    █▀    ███    █▀  ███         ███    █▀                  
         ███   ███   ███ ███    ███  ▄███         ▄███        ███        ▄███▄▄▄                     
         ███   ███   ███ ███    ███ ▀▀███ ████▄  ▀▀███ ████▄  ███       ▀▀███▀▀▀                     
         ███   ███   ███ ███    ███   ███    ███   ███    ███ ███         ███    █▄                  
         ███   ███   ███ ███    ███   ███    ███   ███    ███ ███▌    ▄   ███    ███                 
          ▀█   ███   █▀  ████████▀    ████████▀    ████████▀  █████▄▄██   ██████████                 
                                                              ▀                       
                 """)

    # These are the options when they type the alternatives
    #also used upper so they can put in lower or upper case and still be a valid answer
    if sorting_hat.upper() == 'A':
        house_name = "Gryffindor 🦁"
    elif sorting_hat.upper() == 'B':  
        house_name = "Hufflepuff 🐼"
    elif sorting_hat.upper() == 'C':
        house_name = "Ravenclaw 🦅"
    elif sorting_hat.upper() == 'D':
        house_name = "Slytherin 🐍"
    else:
        house_name = "unknown"

    # Congratulate player with their selected house name
    print(f"Congratulatons! I can see you are a true {house_name}\n")  

    prompt_seat = "Press to < Enter > to go to your seat 🪑"
    input(prompt_seat)


    # Story build up, still in the great hall! I added some color so they dont get lost on the reading and scrolling
    #green color
    print(f"""
     \033[32m 
    {'/' * 80}

    Oh no! Voldemort just interrupted the ceremony, you have to collect the Deathly Hallows in order to defeat him.

    {'/' * 80}\n""")
    
    #Harry appears! and tell the player some instructions
    print(f"""
    \033[30mHarry Potter just came to you {name}, and asked you to help him find the Deathly Hallows.\n """)

    prompt_wand = "Press to < Enter > to grab your 🪄Wand🪄"
    input(prompt_wand)
    

    #This question will help the player have a clear knoweledge of what he or she has to retrieve
    while True:
        choice = input(f"""
              _
          /b_,dM\__,_
        _/MMMMMMMMMMMm,
       _YMMMMMMMMMMMM(
      `MMMMMM/   /   \   "You know what are the Deathly Hallows, 
       MMM|  __  / __/     don´t you {name}?" 
       YMM/_/# \__/# \    
       (.   \__/  \__/     
         )       _,  |    
    _____/\     _   /       
        \  `._____,'
         `..___(__
                  ``-.
                      \


    Select correctly,
       A. Yes, The Triwizarding Cup, The Elder Wand, Dobby
       B. Of course! A phoenix, the Invisibility Cloak and Nearly Headless Nick
       C. Definitely the Invisibility Cloak, The Elder Wand and The Resurrection Stone
       D. I think The Elder wand, The Triwizarding Cup, Godric´s Sword
        """)

        #Establish the correct choice
        if choice.upper() == "C":
            print("""\n\nGood Job! Whomever holds these 3 items will be the most powerful wizard of all.
    My dad left me the invisibility cloak, wicked right? I have it in the Gryffindor
    Common Room, let's go get it so we can walk unseen. Fast!""")
            break

        else:
            print("Incorrect, please try again.") 

great_hall_stg1()
#Second Stage begins
def gryffindor_commons_stg2():

#here I indicate the player they are in the gryffindor common room
    print("""\n\n After running, and almost out of breath you stare at a big portrait.
             _
          /b_,dM\__,_
        _/MMMMMMMMMMMm,
       _YMMMMMMMMMMMM(
      `MMMMMM/   /   \   "The Gryffindor Common Room is guarded by the  
       MMM|  __  / __/     Fat Lady´s Portrait." 
       YMM/_/# \__/# \    
       (.   \__/  \__/     
         )       _,  |    
    _____/\     _   /       
        \  `._____,'
         `..___(__
                  ``-.
                      \
                        """)

    input("Press < Enter > continue \n")
    #Asking for the password 
    print("The Fat Lady stares at you both and says: Password?")

    import random 

    # creating a list for the password
    password_lst = ['C', 'a', 'p', 'u', 't', ' ', 'D', 'r', 'a', 'c', 'o', 'n', 'i', 's']

    # joining the password together
    correct_password = ''.join(password_lst)

    # shuffling the password
    random.shuffle(password_lst)

    print(password_lst)
    #I´ll give the player a hint to get Caput Draconis
    while True:
        print("\nYou can type hint to get one")
        password = input("Enter the password:")
        if  password.lower() == "hint":
            print("Google: Dragon head in latin. Starts with a C")
        elif password.lower() == correct_password.lower() :
            print("\nGreat Job! Wait for me here while I bring my invisibility cloak")
            decision = input("Would you like to wait for Harry 🕑(y/n)")
            if decision.lower() == "y":
                print("Great!")
            else:
                print("Oh no, you´ve surrendered, behind you is a troll with Bellatrix who kills you with an Avadacadabra")
                fail()
            break
        
        else:
            password.lower() != password
            print("Incorrect")

    
    
    #making another ASCII for a beutiful dobby and  in color for engagement
    print(f"""\033[95m Suddenly, someone apparates!

    ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣠⣤⣤⣤⣤⣤⣤⣀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣶⠟⠛⠋⠉⠉⠉⠉⠉⠉⠉⠉⠙⠛⠳⢶⣦⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⡿⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠻⣶⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣾⠏⠀⠀⠀⠀⠀⢾⣦⣄⣀⡀⣀⣠⣤⡶⠟⠀⠀⠀⠀⠀⠀⠈⠻⣷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⣤⣴⡿⠃⠀⣶⠶⠶⠶⠶⣶⣬⣉⠉⠉⠉⢉⣡⣴⡶⠞⠛⠛⠷⢶⡆⠀⠀⠈⢿⠶⠖⠚⠛⠷⠶⢶⣶⣤⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀�
��⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠰⡀⡠⠄⠘⡄⠀⠨⠈⠀⠌⠀⠀⠀⠀⠀⠀⠀⠻⣧⡀⠙⠻⢷⣦⣄⣀⣤⣤⣶⠾⠛⠁⢀⣴⠟⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠐⠻⡄⠀⠀⠉⢆⠈⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣷⣄⡀⠀⠀⠀⠀⠀⠀⢀⣠⣾⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
    ⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠛⠿⠷⠶⠶⠾⠟⠛⠛⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀

    "Master sends {name} the invisibility cloak. 
    He said to Dumbledore's Office you must go and the Elder Wand you will fiiiind." 
      """)

    input("\033[30mPress < Enter > to put on the invisibility cloak and head to Dumbledore´s Office \033[30m\n")
    
    
    
    
gryffindor_commons_stg2()
#Stage 3 in the headmasters tower where Dumbledore´s office is
def headmasters_tower_stg3(): 
    #another challenge to ge the elder wand with alternatives a, b and c
    while True:
        choice_2 = input(r""" You arrive to the Headmaster´s Tower and you see a Griffith waiting for a password

      _/|       |\_
     /  |       |  \
    |    \     /    |
    |  \ /     \ /  |
    | \  |     |  / |
    | \ _\_/^\_/_ / |
    |    --\//--    |
     \_  \     /  _/
       \__  |  __/
          \ _ /
         _/   \_   
        / _/|\_ \  
         /  |  \   
          / v \

    In order to enter you have to solve the folowing conundrum, "Which came first, the phoenix or the flame"?
       A. The Flame!
       B. The Phoenix
       C. A circle has no beggining and no end 

        """)
        #I used upper case to validate lower or upper case when inputted
        if choice_2.upper() == "C":
            print("""\n \033[30m Correct! Something to think about, right? """)
            decision = input("Would you like to enter Dumbledore´s Office(y/n)")
            
        #nested condtional 
            if decision.lower() == "y":
                print("\nGreat!")
        #in case they want to exit the game they go to fail
            else:
                print("Oh no, you´ve surrendered, behind you is a troll with Bellatrix who kills you with an Avadacadabra")
                fail()
            break

        else:
            print("Try again") 
#describing dumbledores office to maintain the player entertained
    print(""" \n\nYou enter the Headmaster´s office which is big and circular, full
    of portraits of old headmasters and headmistresses and begin your search 
    for the Elder wand. Suddenly you see it by the pensieve!""")     
    #Elder wand captured
    input("\nPress < Enter > to grab the Elder Wand \n")

    print(f"""\033[92m \n\n Just in time! Harry os here to pick you up,
             _
          /b_,dM\__,_
        _/MMMMMMMMMMMm,
       _YMMMMMMMMMMMM(
      `MMMMMM/   /   \   "Great {name}! so glad you found it.   
       MMM|  __  / __/     Lets go to the Forbidden Forest where Voldemort is waiting" 
       YMM/_/# \__/# \    
       (.   \__/  \__/     
         )       _,  |    
    _____/\     _   /       
        \  `._____,'
         `..___(__
                  ``-.
                      \
                        """)
#Pressing enter to continue
    input("Press < Enter > to go to the Forbidden Forest \n")
    
headmasters_tower_stg3() 
#Forbidden forest FINAL stage begins
def forbidden_forest_stg4():
    
    #Beautiful ASCII tto introduce the final stage

    print(r"""
              /\
             /**\
            /****\   /\
           /      \ /**\
          /  /\    /    \        /\    /\  /\      /\            /\/\/\  /\
         /  /  \  /      \      /  \/\/  \/  \  /\/  \/\  /\  /\/ / /  \/  \
        /  /    \/ /\     \    /    \ \  /    \/ /   /  \/  \/  \  /    \   \
       /  /      \/  \/\   \  /      \    /   /    \
    __/__/_______/___/__\___\__________________________________________________
           _   _   _   _   _   _   _   _   _     _   _   _   _   _   _  
          / \ / \ / \ / \ / \ / \ / \ / \ / \   / \ / \ / \ / \ / \ / \ 
         ( F ( o ( r ( b ( i ( d ( d ( e ( n ) ( F ( o ( r ( e ( s ( t )
          \_/ \_/ \_/ \_/ \_/ \_/ \_/ \_/ \_/   \_/ \_/ \_/ \_/ \_/ \_/ 
          
        """)
    #An ASCII of voldemort with a script
    print("""\033[30mVoldemort rises his wand to attack as soon as he sees you!      
    --.   /|
   _\"/_.'/
 .'._._,.'
 :/ \{}/
 """)
#For loop for the attacks!! 
    attack=['You cast Bombarda','Voldemort attacks you with crucio but misses',
            'You try to take his wand with expelliiarmus','Voldemort barely misses you with a Confringo', 
            'You run', 'He casts an Avada Kadabra but since you have the elder wand the spell bounces back']

    for attack_name in attack:
        print(attack_name)
        input()
        
    input("Press < Enter > to continue \n")
    
forbidden_forest_stg4()

#Goodbye player! Dumbledore ASCII to tell them they won

print(r"""    
              .-----.
     \ ' /   _/    )/
    - ( ) -('---''--)
     / . \((()\^_^/)()
      \\_\ (()_)-((()()               
       '- \ )/\._./(()
         '/\/( X   ) \
         (___)|___/ ) \
              |.#_|(___)
             /\    \ ( (_
             \/\/\/\) \\
             | / \ |
             |(   \|
            _|_)__|_\_
            )...()...(
             | (   \ |     
          .-'__,)  (  \
                   '\_-,
     """)

print(f""" You made it {name}! Voldemort is gone, congratulations you saved us all!
Here is the resurrection stone as a token of our gratitude.\
Hope you visit us again soon!! """)
#End of the game, they can exit
exit()
# Out:
#
# ▄▄▌  ▄▄▄ .▄▄▄▄▄.▄▄ ·      ▄▄ •           ▄▄▄▄▄
# ██•  ▀▄.▀·•██  ▐█ ▀.     ▐█ ▀ ▪▪         •██  ▪
# ██▪  ▐▀▀▪▄ ▐█.▪▄▀▀▀█▄    ▄█ ▀█▄ ▄█▀▄      ▐█.▪ ▄█▀▄
# ▐█▌▐▌▐█▄▄▌ ▐█▌·▐█▄▪▐█    ▐█▄▪▐█▐█▌.▐▌     ▐█▌·▐█▌.▐▌
# .▀▀▀  ▀▀▀  ▀▀▀  ▀▀▀▀     ·▀▀▀▀  ▀█▄▀▪     ▀▀▀  ▀█▄▀▪
#  ▄ .▄       ▄▄ • ▄▄▌ ▐ ▄▌ ▄▄▄· ▄▄▄  ▄▄▄▄▄.▄▄ ·
# ██▪▐█▪     ▐█ ▀ ▪██· █▌▐█▐█ ▀█ ▀▄ █·•██  ▐█ ▀.
# ██▀▐█ ▄█▀▄ ▄█ ▀█▄██▪▐█▐▐▌▄█▀▀█ ▐▀▀▄  ▐█.▪▄▀▀▀█▄
# ██▌▐▀▐█▌.▐▌▐█▄▪▐█▐█▌██▐█▌▐█ ▪▐▌▐█•█▌ ▐█▌·▐█▄▪▐█
# ▀▀▀ · ▀█▄▀▪·▀▀▀▀  ▀▀▀▀ ▀▪ ▀  ▀ .▀  ▀ ▀▀▀  ▀▀▀▀
#
#                              .-----.
#                           .'       `.
#                          :      ^v^  :
#                          :           :
#                          '           '
#           |~        www   `.       .'
#          /.\       /#^^\_   `-/\--'
#         /#  \     /#%    \   /# \
#        /#%   \   /#%______\ /#%__\
#       /#%     \   |= I I ||  |- |
#       ~~|~~~|~~   |_=_-__|'  |[]|
#         |[] |_______\__|/_ _ |= |`.
# ...
